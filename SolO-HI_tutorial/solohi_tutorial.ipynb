# %%
runfile('shifits2grid.py')

# %%
data_path='sample_data/L2/'
date=['20220402', '20220403']

# %%
hdr,img,inx=match_files(date, path=data_path)

# %%
# %matplotlib inline
plt.imshow(img[41,:,:], vmin=0, vmax=100, cmap='gray', origin='lower')

# %%
cub, hdrs = shi_mov_cube(hdr, img, inx)

# %%
plt.imshow(cub[39,:,:], vmin=0, vmax=50, cmap='gray', origin='lower')

# %%
outcub=process_cube(cub, ratio=1)

# %%
plt.imshow(outcub[40,:,:], vmin=.99, vmax=1.01, cmap='gray', origin='lower')

# %%
# %matplotlib notebook
plt.rcParams['animation.ffmpeg_path'] = '/usr/local/bin/ffmpeg'

# %%
run_movie(outcub, hdrs=hdrs[1::], grid=True, vrange=[.99, 1.01], moviepath='/Users/phess/', moviename='test2.mp4')
# Out:
# Launching animation...
# <img src="data:image/png;base64,..." width="432">
# Rendering frame  1 of 111
# Rendering frame  2 of 111
# Rendering frame  3 of 111
# Rendering frame  4 of 111
# Rendering frame  5 of 111
# Rendering frame  6 of 111
# Rendering frame  7 of 111
# Rendering frame  8 of 111
# Rendering frame  9 of 111
# Rendering frame  10 of 111
# Rendering frame  11 of 111
# Rendering frame  12 of 111
# Rendering frame  13 of 111
# Rendering frame  14 of 111
# Rendering frame  15 of 111
# Rendering frame  16 of 111
# Rendering frame  17 of 111
# Rendering frame  18 of 111
# Rendering frame  19 of 111
# Rendering frame  20 of 111
# Rendering frame  21 of 111
# Rendering frame  22 of 111
# Rendering frame  23 of 111
# Rendering frame  24 of 111
# Rendering frame  25 of 111
# Rendering frame  26 of 111
# Rendering frame  27 of 111
# Rendering frame  28 of 111
# Rendering frame  29 of 111
# Rendering frame  30 of 111
# Rendering frame  31 of 111
# Rendering frame  32 of 111
# ...

# %%
# %matplotlib inline
imp=proj_img(hdrs[41], outcub[40,:,:], display=True, vrange=[.99,1.01])

# %%
# %matplotlib notebook
proj_movie(outcub, hdrs[1::], vrange=[.99, 1.01], moviepath='/Users/phess/', moviename='test3.mp4')
# Out:
# Launching animation...
# <img src="data:image/png;base64,..." width="432">
# Rendering frame  1 of 111
# Rendering frame  2 of 111
# Rendering frame  3 of 111
# Rendering frame  4 of 111
# Rendering frame  5 of 111
# Rendering frame  6 of 111
# Rendering frame  7 of 111
# Rendering frame  8 of 111
# Rendering frame  9 of 111
# Rendering frame  10 of 111
# Rendering frame  11 of 111
# Rendering frame  12 of 111
# Rendering frame  13 of 111
# Rendering frame  14 of 111
# Rendering frame  15 of 111
# Rendering frame  16 of 111
# Rendering frame  17 of 111
# Rendering frame  18 of 111
# Rendering frame  19 of 111
# Rendering frame  20 of 111
# Rendering frame  21 of 111
# Rendering frame  22 of 111
# Rendering frame  23 of 111
# Rendering frame  24 of 111
# Rendering frame  25 of 111
# Rendering frame  26 of 111
# Rendering frame  27 of 111
# Rendering frame  28 of 111
# Rendering frame  29 of 111
# Rendering frame  30 of 111
# Rendering frame  31 of 111
# Rendering frame  32 of 111
# ...

# %%
jmov=jmovie(outcub, hdrs[1::])
# Out:
# Projecting frame:  1  of  111
# Projecting frame:  2  of  111
# Projecting frame:  3  of  111
# Projecting frame:  4  of  111
# Projecting frame:  5  of  111
# Projecting frame:  6  of  111
# Projecting frame:  7  of  111
# Projecting frame:  8  of  111
# Projecting frame:  9  of  111
# Projecting frame:  10  of  111
# Projecting frame:  11  of  111
# Projecting frame:  12  of  111
# Projecting frame:  13  of  111
# Projecting frame:  14  of  111
# Projecting frame:  15  of  111
# Projecting frame:  16  of  111
# Projecting frame:  17  of  111
# Projecting frame:  18  of  111
# Projecting frame:  19  of  111
# Projecting frame:  20  of  111
# Projecting frame:  21  of  111
# Projecting frame:  22  of  111
# Projecting frame:  23  of  111
# Projecting frame:  24  of  111
# Projecting frame:  25  of  111
# Projecting frame:  26  of  111
# Projecting frame:  27  of  111
# Projecting frame:  28  of  111
# Projecting frame:  29  of  111
# Projecting frame:  30  of  111
# ...

# %%
# %matplotlib inline
jmap=make_jmap(jmov, hdrs[1::], vrange=[.997, 1.003], pa=94, outx=1000, unit='Rs')
